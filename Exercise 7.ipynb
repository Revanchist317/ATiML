# %% [markdown]
# # Assignment 7

# %% [markdown]
# ## Assignment 7.1

# %% [markdown]
# Describe in a few words the goal of Semi-Supervised Learning. What problems are there? What challenges?

# %% [markdown]
# ## Assignment 7.2

# %% [markdown]
# Consider real numbers as our data objects. Given are two data points 1 and 10. Point 1 is labeled as one class (rectangle), point 10 as another class (circle). Use the nearest neighbor classifier for the classification of a new instance.

# %% [markdown]
# a) How would a new data point 7 be labeled?
# <div align="center">
# <img src="attachment:6779dc1f-9e3a-441b-bf06-9a89ced7a4ba.png" width=750/>
# </div>

# %% [markdown]
# b) Now assume that we have given more unlabeled data. How would point 7 be labeled after applying self-learning? Show each step of the algorithm.
# <div align="center">
# <img src="attachment:5656ca64-a3b8-4d70-9b36-c01657ee03a1.png" width=750/>
# </div>

# %% [markdown]
# c) Discuss in general which kind of unlabeled data most likely improves classification quality and which does not.

# %% [markdown]
# ## Assignment 7.3

# %% [markdown]
# Consider the following 2D data set and again a nearest neighbor classifier:
# <div align="center">
# <img src="attachment:07974b5e-b62a-4c18-b3b8-d689b1465b34.png" width=450/>
# </div>

# %% [markdown]
# a) If point (3,2) is labeled as + and point (7,3.5) is labeled as −, how would that affect self-training, if you always would classify the most confident point next? (Hint: The most confident point in this case is the nearest one.)

# %% [markdown]
# b) What would a better initial labeling be and why? How would it affect the self- training process in this case?

# %% [markdown]
# ## Assignment 7.4

# %% [markdown]
# What is a generative model? How do they relate to clustering? Give examples for generative models. What are advantages and disadvantages?
